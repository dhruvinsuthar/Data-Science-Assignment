# %%
# Q1: What is Estimation Statistics? Explain point estimate and interval estimate.
# Estimation statistics is a method used to infer the value of population parameters based on sample data. 
# Point Estimate: A single value that serves as an estimate of a population parameter (e.g., sample mean).
# Interval Estimate: A range of values, called a confidence interval, within which the parameter is expected to lie.

# %%
# Q2. Write a Python function to estimate the population mean using a sample mean and standard deviation.
import scipy.stats as stats

def estimate_mean(sample_mean, sample_std, sample_size):
    margin_error = stats.t.ppf(0.975, df=sample_size - 1) * (sample_std / (sample_size ** 0.5))
    return (sample_mean - margin_error, sample_mean + margin_error)

# %%
# Q3: What is Hypothesis testing? Why is it used? State the importance of Hypothesis testing.
# Hypothesis testing is a statistical method used to make decisions or inferences about population parameters.
# Importance:
# - Validates assumptions about data.
# - Supports decision-making based on evidence.
# - Determines relationships or differences between groups.

# %%
# Q4. Create a hypothesis that states whether the average weight of male college students is greater than the average weight of female college students.
# H0: Average weight of male students <= Average weight of female students.
# H1: Average weight of male students > Average weight of female students.

# %%
# Q5. Write a Python script to conduct a hypothesis test on the difference between two population means, given a sample from each population.
from scipy import stats
import numpy as np

sample1 = np.random.normal(70, 10, 30)
sample2 = np.random.normal(65, 8, 40)
stat, p_value = stats.ttest_ind(sample1, sample2)
print(f"t-statistic: {stat}, p-value: {p_value}")
# Out:
# t-statistic: 1.0347262938955988, p-value: 0.30446261844360556

# %%
# Q6: What is a null and alternative hypothesis? Give some examples.
# Null Hypothesis (H0): Assumes no effect or difference.
# Alternative Hypothesis (H1): Assumes presence of an effect or difference.
# Example:
# H0: A new drug has no effect on blood pressure.
# H1: A new drug reduces blood pressure.

# %%
# Q7: Write down the steps involved in hypothesis testing.
# 1. State the null and alternative hypotheses.
# 2. Choose a significance level (α).
# 3. Calculate the test statistic.
# 4. Compute the p-value.
# 5. Make a decision (reject or fail to reject H0).

# %%
# Q8. Define p-value and explain its significance in hypothesis testing.
# p-value: The probability of obtaining the observed results assuming the null hypothesis is true.
# Significance:
# - p < α: Reject H0 (significant result).
# - p >= α: Fail to reject H0 (not significant).

# %%
# Q9. Generate a Student's t-distribution plot using Python's matplotlib library, with the degrees of freedom parameter set to 10.
import matplotlib.pyplot as plt
from scipy.stats import t
import numpy as np

x = np.linspace(-4, 4, 100)
plt.plot(x, t.pdf(x, 10))
plt.title("Student's t-distribution (df=10)")
plt.show()

# %%
# Q10. Write a Python program to calculate the two-sample t-test for independent samples, given two random samples of equal size and a null hypothesis that the population means are equal.
def two_sample_ttest(data1, data2):
    stat, p = stats.ttest_ind(data1, data2)
    return stat, p

# %%
# Q11: What is Student’s t distribution? When to use the t-Distribution.
# The Student's t-distribution is used for hypothesis testing and confidence intervals when the sample size is small or the population standard deviation is unknown.

# %%
# Q12: What is t-statistic? State the formula for t-statistic.
# t-statistic measures the difference between sample means relative to their variability.
# Formula: t = (x1 - x2) / sqrt(s1^2/n1 + s2^2/n2)

# %%
# Q13. A coffee shop owner wants to estimate the average daily revenue for their shop. They take a random sample of 50 days and find the sample mean revenue to be $500 with a standard deviation of $50. Estimate the population mean revenue with a 95% confidence interval.
sample_mean = 500
sample_std = 50
n = 50
margin_error = stats.t.ppf(0.975, n-1) * (sample_std / (n ** 0.5))
conf_interval = (sample_mean - margin_error, sample_mean + margin_error)
print(f"95% Confidence Interval: {conf_interval}")
# Out:
# 95% Confidence Interval: (np.float64(485.79015722521353), np.float64(514.2098427747865))

# %%
# Q14. A researcher hypothesizes that a new drug will decrease blood pressure by 10 mmHg. They conduct a clinical trial with 100 patients and find that the sample mean decrease in blood pressure is 8 mmHg with a standard deviation of 3 mmHg. Test the hypothesis with a significance level of 0.05.
sample_mean = 8
pop_mean = 10
std_dev = 3
n = 100
z = (sample_mean - pop_mean) / (std_dev / (n ** 0.5))
p_value = stats.norm.cdf(z)
print(f"p-value: {p_value}")
# Out:
# p-value: 1.3083924686052994e-11

# %%
# Q15. An electronics company produces a certain type of product with a mean weight of 5 pounds and a standard deviation of 0.5 pounds. A random sample of 25 products is taken, and the sample mean weight is found to be 4.8 pounds. Test the hypothesis that the true mean weight of the products is less than 5 pounds with a significance level of 0.01.
sample_mean = 4.8
pop_mean = 5
std_dev = 0.5
n = 25
z = (sample_mean - pop_mean) / (std_dev / (n ** 0.5))
p_value = stats.norm.cdf(z)
print(f"p-value: {p_value}")
# Out:
# p-value: 0.0227501319481791

# %%
# Q16. Two groups of students are given different study materials to prepare for a test. The first group (n1 = 30) has a mean score of 80 with a standard deviation of 10, and the second group (n2 = 40) has a mean score of 75 with a standard deviation of 8. Test the hypothesis that the population means for the two groups are equal with a significance level of 0.01.
n1, mean1, std1 = 30, 80, 10
n2, mean2, std2 = 40, 75, 8
pooled_std = ((std1**2 / n1) + (std2**2 / n2)) ** 0.5
t_stat = (mean1 - mean2) / pooled_std
df = n1 + n2 - 2
p_value = 2 * (1 - stats.t.cdf(abs(t_stat), df))
print(f"t-statistic: {t_stat}, p-value: {p_value}")
# Out:
# t-statistic: 2.2511258444537408, p-value: 0.027613480367697507

# %%
# Q17. A marketing company wants to estimate the average number of ads watched by viewers during a TV program. They take a random sample of 50 viewers and find that the sample mean is 4 with a standard deviation of 1.5. Estimate the population mean with a 99% confidence interval.
sample_mean = 4
sample_std = 1.5
n = 50
margin_error = stats.t.ppf(0.995, n-1) * (sample_std / (n ** 0.5))
conf_interval = (sample_mean - margin_error, sample_mean + margin_error)
print(f"99% Confidence Interval: {conf_interval}")
# Out:
# 99% Confidence Interval: (np.float64(3.4314963358572577), np.float64(4.568503664142742))
